# %%
# Import the random module
import random
# Import the NumPy module.
import numpy as np
# Import timeit.
import timeit

# %%
random.random()
# Out:
# 0.36198384123845606

# %%
random.randint(-10,10)
# Out:
# -10

# %%
random.randrange(-9,9,2)
# Out:
# 7

# %%
random.uniform(-10,10)
# Out:
# 6.3961674122403025

# %%
random.randint(-90, 90)
# Out:
# -32

# %%
random_number = random.randint(-90, 89) + random.random()
random_number
# Out:
# -40.226554602593275

# %%
x = 1
latitudes = []
while x < 11:
    random_lat = random.randint(-90, 89) + random.random()
    latitudes.append(random_lat)
    x += 1
latitudes
# Out:
# [-59.465342841597646,
#  -32.2119881761072,
#  69.38456860533772,
#  64.56496394318333,
#  -51.173493946484115,
#  7.272298807469333,
#  41.92798050219436,
#  42.4571109536844,
#  -78.49829734928113,
#  22.3656278557032]

# %%
random.randrange(-90, 90, step=1)
# Out:
# 32

# %%
random.randrange(-90, 90, step=3)
# Out:
# 63

# %%
random.uniform(-90, 90)
# Out:
# 34.2451739446044

# %%
np.random.uniform(-90.000, 90.000)
# Out:
# 7.720910853511469

# %%
np.random.uniform(low=-90, high=90)
# Out:
# -46.709284922770884

# %%
np.random.uniform(-90.000, 90.000, size=50)
# Out:
# array([ 34.50858412, -67.40312119, -49.0019006 ,  -3.41927715,
#         51.11248924, -71.44797177, -30.1656858 ,  71.12470223,
#        -16.6011037 ,  -1.83184936, -75.559511  ,  50.32962421,
#        -48.22421736, -65.9308502 ,  89.38250631,   6.85328176,
#        -60.30552587,   4.25291788,  65.31874109,  -8.85650779,
#        -20.63613314,  61.02558824,  36.85173606, -85.32433365,
#         74.21963602, -28.37617656,  89.51090318,  21.44986788,
#         72.99153234, -30.58930547, -23.25442086,  -4.9299422 ,
#         77.09273396,  49.83108731, -40.99162737,  22.52358047,
#        -61.96289808,  30.33977682,  43.54977564, -86.11178167,
#        -69.2386673 ,  18.2876203 ,  69.59087178,  46.2686653 ,
#        -64.53399271, -76.08963372,  -9.33273021, -72.19273751,
#         12.92677068, -27.79250027])

# %%
# %timeit np.random.uniform(-90.000, 90.000, size=1500)
# Out:
# 15.5 µs ± 188 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %%
def latitudes(size):
    latitudes = []
    x = 0
    while x < (size):
        random_lat = random.randint(-90, 90) + random.random()
        latitudes.append(random_lat)
        x += 1
    return latitudes
# Call the function with 1500.
# %timeit latitudes(1500)
# Out:
# 2.47 ms ± 97.3 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
